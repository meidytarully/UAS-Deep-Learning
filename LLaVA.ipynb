# %% [markdown]
# <a href="https://colab.research.google.com/github/meidytarully/UAS-Deep-Learning/blob/main/LLaVA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/haotian-liu/LLaVA.git
# %cd /content/LLaVA

# !pip install -q transformers==4.36.2
# !pip install ninja
# !pip install flash-attn --no-build-isolation

# !pip install -e .

# !python -m llava.serve.cli \
#     --model-path 4bit/llava-v1.5-7b-5GB \
#     --image-file "https://llava-vl.github.io/static/images/view.jpg" \
#     --load-8bit
# Out:
# /content
# fatal: destination path 'LLaVA' already exists and is not an empty directory.
# /content/LLaVA
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.1.3 requires tokenizers<0.14,>=0.12.1, but you have tokenizers 0.15.0 which is incompatible.
# llava 1.1.3 requires transformers==4.31.0, but you have transformers 4.36.2 which is incompatible.
# ...
# Obtaining file:///content/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached transformers-4.31.0-py3-none-any.whl (7.4 MB)
# ...
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# ...

# %%
import threading
import subprocess
threading.Thread(target=lambda: subprocess.run(['python3', '-m', 'llava.serve.controller', '--host', '0.0.0.0', '--port', '10000'], check=True), daemon=True).start()

# %%
import threading
import subprocess
command = [
    'python3', '-m', 'llava.serve.model_worker',
    '--host', '0.0.0.0',
    '--controller', 'http://localhost:10000',
    '--port', '40000',
    '--worker', 'http://localhost:40000',
    '--model-path', '4bit/llava-v1.5-7b-5GB',
    '--load-8bit'
]
threading.Thread(target=lambda: subprocess.run(command, check=True, shell=False), daemon=True).start()

# %%
# !python3 -m llava.serve.gradio_web_server --controller http://localhost:10000 --model-list-mode reload --share
# Out:
# 2024-01-03 13:26:35.216398: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-03 13:26:35.218100: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-03 13:26:35.221348: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-03 13:26:40.032708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-03 13:26:45 | INFO | gradio_web_server | args: Namespace(host='0.0.0.0', port=None, controller_url='http://localhost:10000', concurrency_count=10, model_list_mode='reload', share=True, moderate=False, embed=False)
# ...
